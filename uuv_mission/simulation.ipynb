# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Users\\xueya\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\xueya\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\xueya\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\xueya\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\Users\\xueya\\Desktop\\OX\\b1-coding-practical-mt25\\venv', '', 'c:\\Users\\xueya\\Desktop\\OX\\b1-coding-practical-mt25\\venv\\Lib\\site-packages']

# %%
# Import relevant modules

# import from dynamic.py
from dynamic import Submarine, ClosedLoop, Mission

# import your controller class from control.py
from control import Controller

# Instantiate your controller
controller = Controller()  # Adjust parameters as needed
sub = Submarine()
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.random_mission(100, 2)

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
